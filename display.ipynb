# %%
# %load_ext autoreload
# %autoreload 2

from clustering import *
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
N = 1000
D = 2
m = 500
K = 7
SEED = 12
np.random.seed(SEED)

# %%
X, Y = make_blobs(n_samples=N, n_features=D, centers=K, random_state=SEED)

# %%
model = CKM(K=K, m=500, lower=np.min(X), upper=np.max(X), init_centroids=InitCentroids.UNIFORM)

# %%
model.fit(X)
# Out:
# TRAINING: 100%|██████████| 14/14 [00:09<00:00,  1.46it/s]

# %%
plt.scatter(x=X[:, 0], y=X[:, 1], c="black", s=0.5)
plt.scatter(x=model.centroids[:, 0], y=model.centroids[:, 1], c="red", s=20)
plt.show()
plt.close()

# %%
model.predict(X)[:10]
# Out:
# array([0, 2, 2, 1, 2, 1, 0, 0, 0, 1], dtype=int64)
